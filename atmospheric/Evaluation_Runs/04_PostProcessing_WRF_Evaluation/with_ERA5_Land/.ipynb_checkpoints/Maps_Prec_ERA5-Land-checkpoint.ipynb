# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
import math, time, sys, os
import numpy as np
from numpy import sqrt,cos,ma
from mpl_toolkits.basemap import Basemap
import matplotlib as mpl
import matplotlib.pyplot as plt
import netCDF4 as nc
from   matplotlib.backends.backend_pdf import PdfPages
from   matplotlib.patches import Polygon
from   netCDF4 import Dataset as open_ncfile
from matplotlib.pyplot import figure
import scipy
from scipy.ndimage import convolve1d
from scipy.signal import savgol_coeffs, savgol_filter
from scipy.signal._savitzky_golay import _polyder
from scipy.interpolate import griddata
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
from matplotlib import colors
import matplotlib.patches as patches
import datetime
from datetime import date, timedelta
import os
import subprocess
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from sklearn.metrics import root_mean_squared_error, r2_score
from math import sqrt
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
############################################ Input #######################################
year="1990_2020"
data_era5land="/work/cmcc/vr25423/Project/AdriaClimPlus/data/data_ERA5-Land/processed"
data_wrf="/work/cmcc/vr25423/Project/AdriaClimPlus/evaluation_run_30yrs_ERA5/pp/ERA5-Land/files_tp"
##########################################################################################

# %%
def root_mean_squared_error_calc(true, pred):
    squared_diff = (true - pred) ** 2
    mean_squared_error = np.nanmean(squared_diff)
    return np.sqrt(mean_squared_error)

def r2_score_calc(y_true, y_pred):
    mask = ~np.isnan(y_true) & ~np.isnan(y_pred)
    
    y_true_filtered = y_true[mask]
    y_pred_filtered = y_pred[mask]

    ss_res = np.sum((y_true_filtered - y_pred_filtered) ** 2)
    ss_tot = np.sum((y_true_filtered - np.mean(y_true_filtered)) ** 2)
    
    r2 = 1 - (ss_res / ss_tot)
    return r2

def person_calc(y_true, y_pred):
    mask = ~np.isnan(y_true) & ~np.isnan(y_pred)
    
    y_true_filtered = y_true[mask]
    y_pred_filtered = y_pred[mask]

    corr = np.corrcoef(y_true_filtered, y_pred_filtered)[0,1]
    return corr

# %%
######################### Total precipitation ############################
### winter ###
tp_era5land = open_ncfile(str(data_era5land)+"/ERA5-Land_"+str(year)+"_tp_winter.nc","r")
tp_wrf = open_ncfile(str(data_wrf)+"/prec_wrfout_d01_"+str(year)+"_winter.nc","r")
tp_wrf_winter=tp_wrf.variables["prec"][-1,:,:]-tp_wrf.variables["prec"][0,:,:]
tp_era5land_winter=tp_era5land.variables["tp"][0,:,:]*1000
tp_wrf_remap_winter_m = np.where(np.isnan(tp_era5land_winter), np.nan, tp_wrf_winter)

### spring ###
tp_era5land = open_ncfile(str(data_era5land)+"/ERA5-Land_"+str(year)+"_tp_spring.nc","r")
tp_wrf = open_ncfile(str(data_wrf)+"/prec_wrfout_d01_"+str(year)+"_spring.nc","r")
tp_wrf_spring=tp_wrf.variables["prec"][-1,:,:]-tp_wrf.variables["prec"][0,:,:]
tp_era5land_spring=tp_era5land.variables["tp"][0,:,:]*1000
tp_wrf_remap_spring_m = np.where(np.isnan(tp_era5land_spring), np.nan, tp_wrf_spring)

### summer ###
tp_era5land = open_ncfile(str(data_era5land)+"/ERA5-Land_"+str(year)+"_tp_summer.nc","r")
tp_wrf = open_ncfile(str(data_wrf)+"/prec_wrfout_d01_"+str(year)+"_summer.nc","r")
tp_wrf_summer=tp_wrf.variables["prec"][-1,:,:]-tp_wrf.variables["prec"][0,:,:]
tp_era5land_summer=tp_era5land.variables["tp"][0,:,:]*1000
tp_wrf_remap_summer_m = np.where(np.isnan(tp_era5land_summer), np.nan, tp_wrf_summer)

### autumn ###
tp_era5land = open_ncfile(str(data_era5land)+"/ERA5-Land_"+str(year)+"_tp_autumn.nc","r")
tp_wrf = open_ncfile(str(data_wrf)+"/prec_wrfout_d01_"+str(year)+"_autumn.nc","r")
tp_wrf_autumn=tp_wrf.variables["prec"][-1,:,:]-tp_wrf.variables["prec"][0,:,:]
tp_era5land_autumn=tp_era5land.variables["tp"][0,:,:]*1000
tp_wrf_remap_autumn_m = np.where(np.isnan(tp_era5land_autumn), np.nan, tp_wrf_autumn)

# %%
### Plot ###
###### Input ########
#season='winter'
#season='spring'
#season='summer'
#season='autumn'
#####################

seasons = ['winter', 'spring', 'summer', 'autumn']
for season in seasons:
    fig = plt.figure(figsize=(10, 15))
    
    lat=tp_era5land.variables["latitude"][:]
    lon=tp_era5land.variables["longitude"][:]
    
    min_a=-400
    max_a=400
    min_aa=0
    max_aa=1120
    levels = np.arange(min_a, max_a+50, 50)
    levels_a = np.arange(min_aa, max_aa+100, 100)
    out_lat=tp_era5land.variables["latitude"][:]
    out_lon=tp_era5land.variables["longitude"][:]
    
    projection=ccrs.PlateCarree()
    
    season_data = {
        'winter_wrf': tp_wrf_remap_winter_m,
        'spring_wrf': tp_wrf_remap_spring_m,
        'summer_wrf': tp_wrf_remap_summer_m,
        'autumn_wrf': tp_wrf_remap_autumn_m,
        'winter_era5land': tp_era5land_winter,
        'spring_era5land': tp_era5land_spring,
        'summer_era5land': tp_era5land_summer,
        'autumn_era5land': tp_era5land_autumn
    }
    
    
    season_wrf = season_data[f'{season}_wrf']
    season_era5land = season_data[f'{season}_era5land']
    
    ax1 = plt.subplot(2, 3, 1, projection=projection)
    plt1=ax1.contourf(out_lon, out_lat, season_era5land, levels=levels_a, vmin=min_aa, vmax=max_aa, cmap="jet")
    ax1.set_title(str(year)+': ERA5Land',fontsize=15)
    ax1.tick_params(axis='both', which='major', labelsize=17)
    ax1.set_xlabel("Longitude",fontsize=17)
    ax1.set_ylabel("Latitude",fontsize=17)
    ax1.coastlines()
    ax1.add_feature(cfeature.BORDERS, linestyle='--')
    ax1.set_xticks(np.arange(5, 25, 5))
    ax1.set_yticks(np.arange(30, 50, 2.5))
    cbar1=plt.colorbar(plt1, ax=ax1, orientation='horizontal', fraction=0.046, pad=0.13)
    cbar1.set_label('Acc. Prec (mm)', fontsize=13)  # Set colorbar label font size
    cbar1.ax.tick_params(labelsize=13)  
    cbar1.set_ticks(np.arange(min_aa, max_aa+100, 100))
    for label in cbar1.ax.get_xticklabels():  # For a horizontal colorbar
        label.set_rotation(90)
    
    
    ax2 = plt.subplot(2, 3, 2, projection=projection)
    plt2=ax2.contourf(out_lon, out_lat, season_wrf, levels=levels_a, vmin=min_aa, vmax=max_aa, cmap="jet")
    ax2.set_title(str(year)+': WRF',fontsize=15)
    ax2.tick_params(axis='both', which='major', labelsize=17)
    ax2.set_xlabel("Longitude",fontsize=17)
    ax2.coastlines()
    ax2.add_feature(cfeature.BORDERS, linestyle='--')
    ax2.set_xticks(np.arange(5, 25, 8), crs=projection)
    ax2.set_yticks([])
    ax2.set_ylabel('')
    cbar2=plt.colorbar(plt2, ax=ax2, orientation='horizontal', fraction=0.046, pad=0.13)
    cbar2.set_label('Acc. Prec (mm)', fontsize=13)  # Set colorbar label font size
    cbar2.ax.tick_params(labelsize=13)  
    cbar2.set_ticks(np.arange(min_aa, max_aa+100, 100))
    for label in cbar2.ax.get_xticklabels():  # For a horizontal colorbar
        label.set_rotation(90)
    
    ax3 = plt.subplot(2, 3, 3, projection=projection)
    bias=season_wrf-(season_era5land)
    plt3=plt.contourf(out_lon, out_lat, bias, levels=levels, vmin=min_a, vmax=max_a, cmap="RdBu_r")
    ax3.set_title(str(year)+': BIAS',fontsize=15)
    ax3.tick_params(axis='both', which='major', labelsize=17)
    ax3.coastlines()
    ax3.set_xlabel("Longitude",fontsize=17)
    ax3.add_feature(cfeature.BORDERS, linestyle='--')
    ax3.set_xticks(np.arange(5, 25, 5), crs=projection)
    ax3.set_yticks([])
    ax3.set_ylabel('')
    cbar3=plt.colorbar(plt3, ax=ax3, orientation='horizontal', fraction=0.046, pad=0.13)
    cbar3.set_label('mm', fontsize=13, labelpad=-5)  # Set colorbar label font size
    cbar3.ax.tick_params(labelsize=13)  
    cbar3.set_ticks(np.arange(min_a, max_a+100, 100))
    for label in cbar3.ax.get_xticklabels():  # For a horizontal colorbar
        label.set_rotation(90)
    
    bias_med_d = np.nanmean(season_wrf)
    bias_era5land_d = np.nanmean(season_era5land)
    rmse_d = root_mean_squared_error_calc((season_era5land), season_wrf)
    #nrmse_stdv_d = rmse_d / np.nanstd(season_era5land)
    nrmse_stdv_d = rmse_d / (np.nanmax(season_era5land)-np.nanmin(season_era5land))
    r2_d = np.square(person_calc(season_era5land.flatten(), season_wrf.flatten()))
    
    
    ax4 = plt.subplot(2, 3, 4)
    table_data = [[f"Mean \nERA5Land: \n{bias_era5land_d:.2f} (mm)",f"Mean \nwrf: \n{bias_med_d:.2f} (mm)", f"Mean \nbias: \n{np.nanmean(bias):.2f} (mm)", f"RMSE: \n{rmse_d:.2f} (mm)", 
                   f"NRMSE: \n{nrmse_stdv_d:.2f}", f"R2: \n{r2_d:.2f}"]]
    table = ax4.table(cellText=table_data, cellLoc='center', loc='center')
    ax4.axis('off')
    
    table.auto_set_font_size(False)
    table.set_fontsize(11)
    table.scale(3, 4)  # Adjust the scaling if necessary
    
    # Hide the cell borders to make it consistent with the plots
    for key, cell in table.get_celld().items():
        cell.set_linewidth(1)  # Set the border line width to 0 to remove borders
    pos_ax2 = ax2.get_position()
    ax4.set_position([pos_ax2.x0-0.01, pos_ax2.y0-0.29, pos_ax2.width*1.15, pos_ax2.height*2.0])
    
    plt.title(season,fontsize=20, y=1.45)
    plt.show()
